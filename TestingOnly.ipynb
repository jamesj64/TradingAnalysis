# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
import yfinance as yf

import importlib

import Instrument

import SMABacktester

import MomentumContrarian

importlib.reload(Instrument)

importlib.reload(SMABacktester)

importlib.reload(MomentumContrarian)

plt.style.use("seaborn-v0_8")

# %%
Instrument = Instrument.Instrument
SMABacktester = SMABacktester.SMABacktester
MomentumContrarian = MomentumContrarian.MomentumContrarian

# %%
eurUsd = Instrument("EURUSD=X", "2015-01-01", "2023-07-19")
eurUsd
# Out:
# [*********************100%***********************]  1 of 1 completed
# Instrument(ticker=EURUSD=X, start=2015-01-01, end=2023-07-19)

# %%
eurUsd.annualized_performance()
# Out:
# Return: -0.008 | Risk: 0.082

# %%
backtester = SMABacktester.from_instrument(eurUsd, 50, 200)
backtester
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# SMABacktester(symbol=EURUSD=X, start=2015-01-01, end=2023-07-19, SMA_S=50, SMA_L=200)

# %%
backtester.test_strategy()
# Out:
# (1.111173, 0.11387)

# %%
backtester.set_sma_l(32)
backtester.set_sma_l(268)
backtester.test_strategy()
# Out:
# (1.121021, 0.093916)

# %%
backtester.plot_results()

# %%
momentum = MomentumContrarian()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# (1.092597, 0.163057)
