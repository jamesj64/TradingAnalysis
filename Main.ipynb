# %%
from MeanRevBacktester import MeanRevBacktester

# %%
mean_rev = MeanRevBacktester("EURUSD=X", "2015-01-01", "2023-01-01", 30, 2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
